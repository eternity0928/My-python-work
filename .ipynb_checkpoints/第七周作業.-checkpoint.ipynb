# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # (一)方程式出題

# %%
import sympy as sp

# %%
from sympy import S

# %%
S(5)/8
# Out:
# 5/8

# %%
π=np.pi

# %%
x = sp.symbols('x')
y = sp.symbols('y')

# %%
f = 4*x**3 + 5*x**2 + 7*x +6

# %%
f
# Out:
# 4*x**3 + 5*x**2 + 7*x + 6

# %%
sp.plot(f)

# %%
from sympy.abc import x
from sympy.abc import y

# %%
from numpy import random

# %%
a = random.randint(1,10,1)
b = random.randint(1,10,1)
c = random.randint(1,10,1)
y = a*x**2 + b*x + c

# %%
x = sp.symbols('x')
y = sp.symbols('y')

Q=[]
for i in range(1,6):
    a = random.randint(1,10,1)
    b = random.randint(1,10,1)
    c = random.randint(1,10,1)
    y = a*x**2 + b*x + c
    print(y)
    Q.append(y)
# Out:
# [9*x**2 + 3*x + 2]
# [8*x**2 + 9*x + 3]
# [5*x**2 + 7*x + 4]
# [x**2 + 5*x + 1]
# [5*x**2 + 4*x + 9]

# %% [markdown]
# # (二)選出特定的區間

# %%
P = -x**2 - 3*a + 10
sp.plot(P)

# %%
from numpy import linspace

# %%
x = linspace(-10,10,1000)
y = -x**2 - 3*x + 10

# %%
plt.scatter(x[y<0],y[y<0], c='#FF235A')
plt.plot(x,y)

# %% [markdown]
# # (三)迴歸預測練習

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 輸入資料x

# %%
x = np.random.randn(50)

# %%
noise = 0.7*np.random.randn(50) - 0.3

# %% [markdown]
# ### 真的答案y

# %%
y = 1.6*x + 0.75 + noise

# %%
plt.scatter(x,y)

# %%
regr = LinearRegression()

# %%
X = x.reshape(50,1)

# %% [markdown]
# ### 機器學習

# %%
regr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
Y = regr.predict(X)

# %%
plt.scatter(x,y)
plt.plot(x, Y, 'r')
plt.plot(x, 1.6*x + 0.75, 'g')

# %% [markdown]
# # (四)加權平均與排序

# %%
A = np.random.randint(40,100,50)
A
# Out:
# array([88, 81, 49, 79, 80, 57, 78, 50, 46, 60, 73, 41, 43, 72, 54, 81, 58,
#        69, 41, 80, 87, 70, 88, 58, 63, 48, 88, 79, 47, 49, 58, 61, 71, 84,
#        87, 41, 48, 63, 91, 64, 56, 47, 88, 65, 41, 71, 87, 88, 96, 57])

# %%
A = A.reshape(10,5)

# %%
weight = [0.15, 0.15, 0.2, 0.2, 0.3]
W = np.array(weight)
W = W.reshape(5,1)

# %%
A @ W
# Out:
# array([[74.95],
#        [57.45],
#        [56.3 ],
#        [66.85],
#        [71.65],
#        [60.3 ],
#        [74.95],
#        [63.35],
#        [58.35],
#        [77.6 ]])

# %%
G = A @ W

# %%
G = G.reshape(10,1)

# %%
name = ['小明','小花','葳葳','姍姍','艾利','莉比','約翰','喬治','迪西','志明']

# %%
df0 = pd.DataFrame(name, columns = list("N"))
df1= pd.DataFrame(G , columns = list("G"))
df = pd.concat([df0.reset_index(drop = True), df1.reset_index(drop = True)], axis=1)
df.index = range(1,11)
df
# Out:
#      N      G
# 1   小明  74.95
# 2   小花  57.45
# 3   葳葳  56.30
# 4   姍姍  66.85
# 5   艾利  71.65
# 6   莉比  60.30
# 7   約翰  74.95
# 8   喬治  63.35
# 9   迪西  58.35
# 10  志明  77.60

# %% [markdown]
# 按成績高低排序

# %%
df.sort_values(by = "G",ascending = False, inplace = True)
df
# Out:
#      N      G
# 10  志明  77.60
# 1   小明  74.95
# 7   約翰  74.95
# 5   艾利  71.65
# 4   姍姍  66.85
# 8   喬治  63.35
# 6   莉比  60.30
# 9   迪西  58.35
# 2   小花  57.45
# 3   葳葳  56.30
